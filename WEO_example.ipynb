# %% [markdown]
# <a href="https://colab.research.google.com/github/fju155447/WEO/blob/main/WEO_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: import pandas as pd

import pandas as pd

# %%
df =pd.read_csv("https://raw.githubusercontent.com/fju155447/WEO/refs/heads/main/WEO2025.csv")

# %%
df
# Out:
#                                        WEO Country Code  ISO WEO Subject Code  \
# 0                                                   512  AFG           NGDP_R
# 1                                                   512  AFG        NGDP_RPCH
# 2                                                   512  AFG             NGDP
# 3                                                   512  AFG            NGDPD
# 4                                                   512  AFG           PPPGDP
# ...                                                 ...  ...              ...
# 8621                                                698  ZWE          NGDP_FY
# 8622                                                698  ZWE              BCA
# 8623                                                698  ZWE        BCA_NGDPD
# 8624                                                NaN  NaN              NaN
# 8625  International Monetary Fund, World Economic Ou...  NaN              NaN
#
# ...

# %%
df["Country"]=="Zimbabwe"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8621     True
# 8622     True
# 8623     True
# 8624    False
# 8625    False
# Name: Country, Length: 8626, dtype: bool

# %%
df[df["Country"]=="Zimbabwe"]
# Out:
#      WEO Country Code  ISO WEO Subject Code   Country  \
# 8580              698  ZWE           NGDP_R  Zimbabwe
# 8581              698  ZWE        NGDP_RPCH  Zimbabwe
# 8582              698  ZWE             NGDP  Zimbabwe
# 8583              698  ZWE            NGDPD  Zimbabwe
# 8584              698  ZWE           PPPGDP  Zimbabwe
# 8585              698  ZWE           NGDP_D  Zimbabwe
# 8586              698  ZWE          NGDPRPC  Zimbabwe
# 8587              698  ZWE       NGDPRPPPPC  Zimbabwe
# 8588              698  ZWE           NGDPPC  Zimbabwe
# 8589              698  ZWE          NGDPDPC  Zimbabwe
# 8590              698  ZWE            PPPPC  Zimbabwe
# 8591              698  ZWE       NGAP_NPGDP  Zimbabwe
# 8592              698  ZWE            PPPSH  Zimbabwe
# 8593              698  ZWE            PPPEX  Zimbabwe
# 8594              698  ZWE         NID_NGDP  Zimbabwe
# 8595              698  ZWE        NGSD_NGDP  Zimbabwe
# ...

# %%
target = df[df["Country"]=="Zimbabwe"][["Country","WEO Subject Code","Subject Descriptor","Subject Notes","Units","Scale","2005","2006","2007","2008","2009","2010"]]

# %%
target
# Out:
#        Country WEO Subject Code  \
# 8580  Zimbabwe           NGDP_R
# 8581  Zimbabwe        NGDP_RPCH
# 8582  Zimbabwe             NGDP
# 8583  Zimbabwe            NGDPD
# 8584  Zimbabwe           PPPGDP
# 8585  Zimbabwe           NGDP_D
# 8586  Zimbabwe          NGDPRPC
# 8587  Zimbabwe       NGDPRPPPPC
# 8588  Zimbabwe           NGDPPC
# 8589  Zimbabwe          NGDPDPC
# 8590  Zimbabwe            PPPPC
# 8591  Zimbabwe       NGAP_NPGDP
# 8592  Zimbabwe            PPPSH
# 8593  Zimbabwe            PPPEX
# 8594  Zimbabwe         NID_NGDP
# 8595  Zimbabwe        NGSD_NGDP
# 8596  Zimbabwe             PCPI
# 8597  Zimbabwe          PCPIPCH
# 8598  Zimbabwe            PCPIE
# 8599  Zimbabwe         PCPIEPCH
# 8600  Zimbabwe          TM_RPCH
# 8601  Zimbabwe         TMG_RPCH
# 8602  Zimbabwe          TX_RPCH
# 8603  Zimbabwe         TXG_RPCH
# 8604  Zimbabwe              LUR
# 8605  Zimbabwe               LE
# 8606  Zimbabwe               LP
# 8607  Zimbabwe              GGR
# ...

# %%
target[target["WEO Subject Code"] == "GGXWDG"]
# Out:
#        Country WEO Subject Code             Subject Descriptor  \
# 8619  Zimbabwe           GGXWDG  General government gross debt
#
#                                           Subject Notes              Units  \
# 8619  Gross debt consists of all liabilities that re...  National currency
#
#          Scale   2005   2006   2007   2008   2009   2010
# 8619  Billions  0.001  0.001  0.001  0.002  0.002  0.002

# %%
target[target["WEO Subject Code"].isin(["GGXWDG", "GGXWDG_NGDP"])]
# Out:
#        Country WEO Subject Code             Subject Descriptor  \
# 8619  Zimbabwe           GGXWDG  General government gross debt
# 8620  Zimbabwe      GGXWDG_NGDP  General government gross debt
#
#                                           Subject Notes              Units  \
# 8619  Gross debt consists of all liabilities that re...  National currency
# 8620  Gross debt consists of all liabilities that re...     Percent of GDP
#
#          Scale    2005    2006    2007    2008   2009    2010
# 8619  Billions   0.001   0.001   0.001   0.002  0.002   0.002
# 8620     Units  33.062  39.438  44.671  61.078  58.71  47.578

# %%
target[target["WEO Subject Code"].isin(["BCA","BCA_NGDPD","GGXWDG", "GGXWDG_NGDP","NGDP","NGDP","NGDPDPPPGDP","PCPIE","PCPIEPCH","NID_NGDP","TX_RPCH","TM_RPCH"])]
# Out:
#        Country WEO Subject Code                        Subject Descriptor  \
# 8582  Zimbabwe             NGDP    Gross domestic product, current prices
# 8594  Zimbabwe         NID_NGDP                          Total investment
# 8598  Zimbabwe            PCPIE  Inflation, end of period consumer prices
# 8599  Zimbabwe         PCPIEPCH  Inflation, end of period consumer prices
# 8600  Zimbabwe          TM_RPCH   Volume of imports of goods and services
# 8602  Zimbabwe          TX_RPCH   Volume of exports of goods and services
# 8619  Zimbabwe           GGXWDG             General government gross debt
# 8620  Zimbabwe      GGXWDG_NGDP             General government gross debt
# 8622  Zimbabwe              BCA                   Current account balance
# 8623  Zimbabwe        BCA_NGDPD                   Current account balance
#
#                                           Subject Notes              Units  \
# 8582  Expressed in billions of national currency uni...  National currency
# ...

# %%
target[target["WEO Subject Code"]=="GGXWDG"]["2010"]
# Out:
# 8619    0.002
# Name: 2010, dtype: object

# %%
type(target[target["WEO Subject Code"]=="GGXWDG"]["2010"])
# Out:
# pandas.core.series.Series

# %%
TDRS = float(target[target["WEO Subject Code"]=="GGXWDG"]["2010"])*0.0027631943 / float(target[target["WEO Subject Code"]=="BCA"]["2010"])
# Out:
# <ipython-input-70-69665f9fff7f>:1: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   TDRS = float(target[target["WEO Subject Code"]=="GGXWDG"]["2010"])*0.0027631943 / float(target[target["WEO Subject Code"]=="BCA"]["2010"])

# %%
print(TDRS)
# Out:
# -3.3392076132930515e-06

# %%
IR = float(target[target["WEO Subject Code"]=="BCA_NGDPD"]["2010"]) / float(target[target["WEO Subject Code"]=="BCA_NGDPD"]["2006"])-1
# Out:
# <ipython-input-79-8893ee267f8a>:1: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   IR = float(target[target["WEO Subject Code"]=="BCA_NGDPD"]["2010"]) / float(target[target["WEO Subject Code"]=="BCA_NGDPD"]["2006"])-1

# %%
print(IR)
# Out:
# -8.285108638049813

# %%
target[target["WEO Subject Code"]=="BCA_NGDPD"]["2006"]
# Out:
# 8623    1.887
# Name: 2006, dtype: object

# %%
target[target["WEO Subject Code"]=="BCA_NGDPD"]["2010"]
# Out:
# 8623    -13.747
# Name: 2010, dtype: object

# %%
INVR = float(target[target["WEO Subject Code"]== "NID_NGDP"]["2010"])
# Out:
# <ipython-input-83-c1cac019b320>:1: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   INVR = float(target[target["WEO Subject Code"]== "NID_NGDP"]["2010"])

# %%
print(INVR)
# Out:
# nan

# %%
VAREX = target[target["WEO Subject Code"]== "TX_RPCH"][['2006','2007','2008','2009','2010']].T.var()

# %%
print(VAREX)
# Out:
# 8602    NaN
# dtype: object

# %%
MG = float(target[target["WEO Subject Code"]== "PCPIEPCH"]["2010"])

# %%
print(MG)
# Out:
# 3.217
